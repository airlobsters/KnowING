# %% [markdown]
# # Download data
#
# Script to download ING Tweets using the SNScrape package

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

limit = 10000
# Creating list to append tweet data to
attributes_container = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('@ingnl since:2021-06-01 until:2022-11-16').get_items()):
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])  

# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"])

# %%
tweets_df
# Out:
#               User              Date Created  Number of Likes  \
# 0      tonskidutch 2022-11-15 23:49:09+00:00                0
# 1        evenzohar 2022-11-15 22:00:50+00:00                0
# 2         vitallie 2022-11-15 21:17:05+00:00                0
# 3            ingnl 2022-11-15 19:50:12+00:00                0
# 4          brasem5 2022-11-15 19:16:59+00:00                0
# ...            ...                       ...              ...
# 49948    Grippie13 2021-06-01 06:32:16+00:00                0
# 49949    Grippie13 2021-06-01 06:27:12+00:00                0
# 49950        ingnl 2021-06-01 06:07:52+00:00                1
# 49951        ingnl 2021-06-01 06:07:16+00:00                1
# 49952   Gaby93Gaby 2021-06-01 06:06:21+00:00                0
#
#            Source of Tweet                                              Tweet
# 0       Twitter for iPhone  @ingnl Behalve als je wilt verbouwen aan je hu...
# ...

# %%
tweets_df.tail(500)["Tweet"].tolist()
# Out:
# ['@ingnl Alleen briefgeld',
#  '@noman_tee Hi Noman, That is very unfortunate! Are there no specifications as to why when you select the transaction in your Mijn ING-Account? If not, you can call us at +31202288888 so we can take a look as well. This can be done on workdays from 8-21 and Saturdays from 9-17.  ^Franck',
#  '@ingnl arranged a transfer overseas which was reversed for some reason but was still charged over 200 Euros! No communication from the bank to allow rectify any issues. How is that acceptable!',
#  '@ingnl https://t.co/GrdOvO2cFW\n\nING, wat totalitaire houding hebben jullie zeg, mensen beschuldigen in hun privéleven gaat wel erg ver hoor.\n\nWat zou u vinden,als alle klanten tegen u zeggen,geef ons de spaarrente terug,anders gaan we naar een andere bank?',
#  '@gvrtvlknbrg Ja dat kan natuurlijk ook nog, dan lekker niet gaan kijken toch? ^Jildou',
#  '@ingnl Nee, het is meer dat foeballe me gestolen kan worden.',
# ...

# %%
new_df = tweets_df[tweets_df['Tweet'].str.lower().str.contains("@ingnl")]

# %%
new_df.to_csv('cleaned_corpus.csv')

# %%
len(new_df)
# Out:
# 36339
